# %% [markdown]
#  #INTRODUCTION
#
# Real Time Data Fetching is the process of collecting live data from online sources using APIs.
#
# This project fetches real-time weather information using Python and API requests.

# %% [markdown]
#  #OBJECTIVES
#
# -To fetch real-time data using APIs
# -To use Python requests library
# -To display live weather information
# -To understand API integration

# %% [markdown]
#   #TOOLS USED
#
# -Python
# -Requests Library
# -Google Colab
# -API
# -GitHub

# %% [markdown]
# IMPORT LIBRARIES

# %%
# IMPORT LIBRARIES

import requests
import pandas as pd

# %%
# FETCH REAL-TIME WEATHER DATA

url = "https://api.open-meteo.com/v1/forecast?latitude=17.3850&longitude=78.4867&current_weather=true"

response = requests.get(url)

data = response.json()

print(data)
# Out:
# {'latitude': 17.398945, 'longitude': 78.457085, 'generationtime_ms': 0.08428096771240234, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 505.0, 'current_weather_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature': '°C', 'windspeed': 'km/h', 'winddirection': '°', 'is_day': '', 'weathercode': 'wmo code'}, 'current_weather': {'time': '2026-05-25T02:15', 'interval': 900, 'temperature': 30.9, 'windspeed': 13.8, 'winddirection': 307, 'is_day': 1, 'weathercode': 0}}

# %%
# DISPLAY WEATHER INFORMATION

temperature = data['current_weather']['temperature']
windspeed = data['current_weather']['windspeed']
time = data['current_weather']['time']

print("Current Temperature:", temperature, "°C")
print("Wind Speed:", windspeed, "km/h")
print("Time:", time)
# Out:
# Current Temperature: 30.9 °C
# Wind Speed: 13.8 km/h
# Time: 2026-05-25T02:15

# %%
# CONVERT DATA INTO TABLE

weather_df = pd.DataFrame({
    'Temperature (°C)': [temperature],
    'Wind Speed (km/h)': [windspeed],
    'Time': [time]
})

weather_df
# Out:
#    Temperature (°C)  Wind Speed (km/h)              Time
# 0              30.9               13.8  2026-05-25T02:15

# %% [markdown]
#   #CONCLUSION
#
# -Real-time weather data was fetched successfully using API
# -Python requests library was used for API integration
# -Live temperature and wind speed were displayed
# -The fetched data was converted into table format
